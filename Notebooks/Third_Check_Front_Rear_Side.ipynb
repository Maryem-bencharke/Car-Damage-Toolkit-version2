# %%
import os

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Load VGG19 pretrained model and freeze the layers without the FC layers

# %%
from tensorflow.keras.applications import VGG19

# VGG19 was designed to work on 224 x 224 pixel input images sizes
img_rows = 224
img_cols = 224 

# loads the VGG19 model without the top or FC layers
vgg19 = VGG19(weights = 'imagenet', 
                 include_top = False, 
                 input_shape = (img_rows, img_cols, 3))

# Here we freeze the FC layers 
# Layers are set to trainable as True by default
for layer in vgg19.layers:
    layer.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 1s 0us/step
# 80150528/80134624 [==============================] - 1s 0us/step

# %% [markdown]
# Let's make a function that returns our FC Head

# %%
def addTopModel(bottom_model, num_classes, D=512):
    """creates the top or head of the model that will be 
    placed ontop of the bottom layers"""
    top_model = bottom_model.output
    top_model = Flatten(name = "flatten")(top_model)
    top_model = Dense(D, activation = "relu")(top_model)
    top_model = Dense(256, activation = "relu")(top_model)
    top_model = Dropout(0.5)(top_model)
    top_model = Dense(num_classes, activation = "softmax")(top_model)
    return top_model

# %% [markdown]
# Let's add our FC Head back onto VGG

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D, ZeroPadding2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.models import Model

num_classes = 3

FC_Head = addTopModel(vgg19, num_classes)

model = Model(inputs=vgg19.input, outputs=FC_Head)

print(model.summary())
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 512)               12845568
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_2 (Dense)             (None, 3)                 771
#
# =================================================================
# Total params: 33,002,051
# Trainable params: 12,977,667
# Non-trainable params: 20,024,384
# _________________________________________________________________
# None

# %% [markdown]
# Loading our Dataset + Data Augmentation

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_data_dir = '/content/drive/MyDrive/car_damage_dataset/data2a/training'
validation_data_dir = '/content/drive/MyDrive/car_damage_dataset/data2a/validation'

train_datagen = ImageDataGenerator(
      rescale=1./255,
      rotation_range=20,
      width_shift_range=0.2,
      height_shift_range=0.2,
      horizontal_flip=True,
      fill_mode='nearest')
 
validation_datagen = ImageDataGenerator(rescale=1./255)
 
# Change the batchsize according to your system RAM
batchsize = 32

 
train_generator = train_datagen.flow_from_directory(
        train_data_dir,
        target_size=(img_rows, img_cols),
        batch_size=batchsize,
        class_mode='categorical')
 
validation_generator = validation_datagen.flow_from_directory(
        validation_data_dir,
        target_size=(img_rows, img_cols),
        batch_size=batchsize,
        class_mode='categorical',
        shuffle=False)
# Out:
# Found 979 images belonging to 3 classes.
# Found 171 images belonging to 3 classes.

# %% [markdown]
# Training our top layers

# %%
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
                   
checkpoint = ModelCheckpoint("FRS_vgg.h5",
                             monitor="val_loss",
                             mode="min",
                             save_best_only = True,
                             verbose=1)

# earlystop = EarlyStopping(monitor = 'val_loss', 
#                           min_delta = 0, 
#                           patience = 3,
#                           verbose = 1,
#                           restore_best_weights = True)

# we put our call backs into a callback list
# callbacks = [earlystop, checkpoint]

callbacks = [checkpoint]

# Note we use a very small learning rate 
model.compile(loss = 'categorical_crossentropy',
              optimizer = "adam",
              metrics = ['accuracy'])

nb_train_samples = 979
nb_validation_samples = 171
epochs = 25
batch_size = 32

history = model.fit(
    train_generator,
    steps_per_epoch = nb_train_samples // batch_size,
    epochs = epochs,
    callbacks = callbacks,
    validation_data = validation_generator,
    validation_steps = nb_validation_samples // batch_size)

#model.save("FRS_vgg.h5")
# Out:
# Epoch 1/25
# 30/30 [==============================] - ETA: 0s - loss: 0.8149 - accuracy: 0.6399
# Epoch 1: val_loss improved from inf to 0.78505, saving model to FRS_vgg.h5
# 30/30 [==============================] - 16s 528ms/step - loss: 0.8149 - accuracy: 0.6399 - val_loss: 0.7850 - val_accuracy: 0.6625
# Epoch 2/25
# 30/30 [==============================] - ETA: 0s - loss: 0.7742 - accuracy: 0.6758
# Epoch 2: val_loss improved from 0.78505 to 0.73146, saving model to FRS_vgg.h5
# 30/30 [==============================] - 15s 510ms/step - loss: 0.7742 - accuracy: 0.6758 - val_loss: 0.7315 - val_accuracy: 0.6938
# Epoch 3/25
# 30/30 [==============================] - ETA: 0s - loss: 0.7674 - accuracy: 0.6769
# Epoch 3: val_loss did not improve from 0.73146
# 30/30 [==============================] - 15s 484ms/step - loss: 0.7674 - accuracy: 0.6769 - val_loss: 0.7329 - val_accuracy: 0.6875
# Epoch 4/25
# 30/30 [==============================] - ETA: 0s - loss: 0.7321 - accuracy: 0.6895
# Epoch 4: val_loss improved from 0.73146 to 0.70727, saving model to FRS_vgg.h5
# 30/30 [==============================] - 15s 513ms/step - loss: 0.7321 - accuracy: 0.6895 - val_loss: 0.7073 - val_accuracy: 0.7063
# Epoch 5/25
# 30/30 [==============================] - ETA: 0s - loss: 0.7318 - accuracy: 0.6705
# Epoch 5: val_loss improved from 0.70727 to 0.70314, saving model to FRS_vgg.h5
# 30/30 [==============================] - 15s 509ms/step - loss: 0.7318 - accuracy: 0.6705 - val_loss: 0.7031 - val_accuracy: 0.6875
# Epoch 6/25
# 30/30 [==============================] - ETA: 0s - loss: 0.6975 - accuracy: 0.6917
# Epoch 6: val_loss did not improve from 0.70314
# 30/30 [==============================] - 15s 501ms/step - loss: 0.6975 - accuracy: 0.6917 - val_loss: 0.7064 - val_accuracy: 0.7312
# Epoch 7/25
# 30/30 [==============================] - ETA: 0s - loss: 0.6706 - accuracy: 0.7307
# Epoch 7: val_loss did not improve from 0.70314
# 30/30 [==============================] - 15s 498ms/step - loss: 0.6706 - accuracy: 0.7307 - val_loss: 0.7442 - val_accuracy: 0.6562
# Epoch 8/25
# 30/30 [==============================] - ETA: 0s - loss: 0.6436 - accuracy: 0.7360
# Epoch 8: val_loss did not improve from 0.70314
# 30/30 [==============================] - 15s 501ms/step - loss: 0.6436 - accuracy: 0.7360 - val_loss: 0.7663 - val_accuracy: 0.6875
# Epoch 9/25
# 30/30 [==============================] - ETA: 0s - loss: 0.6248 - accuracy: 0.7423
# Epoch 9: val_loss did not improve from 0.70314
# 30/30 [==============================] - 15s 508ms/step - loss: 0.6248 - accuracy: 0.7423 - val_loss: 0.8059 - val_accuracy: 0.6750
# Epoch 10/25
# 30/30 [==============================] - ETA: 0s - loss: 0.6400 - accuracy: 0.7339
# Epoch 10: val_loss did not improve from 0.70314
# 30/30 [==============================] - 15s 500ms/step - loss: 0.6400 - accuracy: 0.7339 - val_loss: 0.7249 - val_accuracy: 0.6812
# Epoch 11/25
# 30/30 [==============================] - ETA: 0s - loss: 0.6164 - accuracy: 0.7508
# Epoch 11: val_loss improved from 0.70314 to 0.69553, saving model to FRS_vgg.h5
# 30/30 [==============================] - 16s 521ms/step - loss: 0.6164 - accuracy: 0.7508 - val_loss: 0.6955 - val_accuracy: 0.6875
# Epoch 12/25
# 30/30 [==============================] - ETA: 0s - loss: 0.5548 - accuracy: 0.7751
# Epoch 12: val_loss did not improve from 0.69553
# 30/30 [==============================] - 15s 494ms/step - loss: 0.5548 - accuracy: 0.7751 - val_loss: 0.7469 - val_accuracy: 0.6875
# Epoch 13/25
# 30/30 [==============================] - ETA: 0s - loss: 0.6616 - accuracy: 0.7233
# Epoch 13: val_loss did not improve from 0.69553
# 30/30 [==============================] - 15s 495ms/step - loss: 0.6616 - accuracy: 0.7233 - val_loss: 0.7989 - val_accuracy: 0.6812
# Epoch 14/25
# 30/30 [==============================] - ETA: 0s - loss: 0.6341 - accuracy: 0.7328
# Epoch 14: val_loss did not improve from 0.69553
# 30/30 [==============================] - 15s 496ms/step - loss: 0.6341 - accuracy: 0.7328 - val_loss: 0.7198 - val_accuracy: 0.7063
# Epoch 15/25
# 30/30 [==============================] - ETA: 0s - loss: 0.5770 - accuracy: 0.7772
# Epoch 15: val_loss did not improve from 0.69553
# 30/30 [==============================] - 15s 494ms/step - loss: 0.5770 - accuracy: 0.7772 - val_loss: 0.7207 - val_accuracy: 0.6750
# Epoch 16/25
# 30/30 [==============================] - ETA: 0s - loss: 0.5596 - accuracy: 0.7666
# Epoch 16: val_loss did not improve from 0.69553
# 30/30 [==============================] - 15s 491ms/step - loss: 0.5596 - accuracy: 0.7666 - val_loss: 0.7727 - val_accuracy: 0.7063
# Epoch 17/25
# 30/30 [==============================] - ETA: 0s - loss: 0.6403 - accuracy: 0.7318
# Epoch 17: val_loss improved from 0.69553 to 0.67438, saving model to FRS_vgg.h5
# 30/30 [==============================] - 15s 507ms/step - loss: 0.6403 - accuracy: 0.7318 - val_loss: 0.6744 - val_accuracy: 0.7250
# Epoch 18/25
# 30/30 [==============================] - ETA: 0s - loss: 0.5654 - accuracy: 0.7804
# Epoch 18: val_loss did not improve from 0.67438
# 30/30 [==============================] - 15s 493ms/step - loss: 0.5654 - accuracy: 0.7804 - val_loss: 0.6807 - val_accuracy: 0.7312
# Epoch 19/25
# 30/30 [==============================] - ETA: 0s - loss: 0.5479 - accuracy: 0.7906
# Epoch 19: val_loss did not improve from 0.67438
# 30/30 [==============================] - 15s 513ms/step - loss: 0.5479 - accuracy: 0.7906 - val_loss: 0.6774 - val_accuracy: 0.7063
# Epoch 20/25
# 30/30 [==============================] - ETA: 0s - loss: 0.5525 - accuracy: 0.7645
# Epoch 20: val_loss did not improve from 0.67438
# 30/30 [==============================] - 15s 495ms/step - loss: 0.5525 - accuracy: 0.7645 - val_loss: 0.7447 - val_accuracy: 0.7250
# Epoch 21/25
# 30/30 [==============================] - ETA: 0s - loss: 0.5612 - accuracy: 0.7592
# Epoch 21: val_loss did not improve from 0.67438
# 30/30 [==============================] - 15s 489ms/step - loss: 0.5612 - accuracy: 0.7592 - val_loss: 0.7199 - val_accuracy: 0.6875
# Epoch 22/25
# 30/30 [==============================] - ETA: 0s - loss: 0.5794 - accuracy: 0.7635
# Epoch 22: val_loss did not improve from 0.67438
# 30/30 [==============================] - 15s 488ms/step - loss: 0.5794 - accuracy: 0.7635 - val_loss: 0.7211 - val_accuracy: 0.7250
# Epoch 23/25
# 30/30 [==============================] - ETA: 0s - loss: 0.5216 - accuracy: 0.8015
# Epoch 23: val_loss did not improve from 0.67438
# 30/30 [==============================] - 15s 497ms/step - loss: 0.5216 - accuracy: 0.8015 - val_loss: 0.7950 - val_accuracy: 0.7000
# Epoch 24/25
# 30/30 [==============================] - ETA: 0s - loss: 0.5148 - accuracy: 0.7930
# Epoch 24: val_loss did not improve from 0.67438
# 30/30 [==============================] - 15s 491ms/step - loss: 0.5148 - accuracy: 0.7930 - val_loss: 0.8536 - val_accuracy: 0.6562
# Epoch 25/25
# 30/30 [==============================] - ETA: 0s - loss: 0.5956 - accuracy: 0.7687
# Epoch 25: val_loss did not improve from 0.67438
# 30/30 [==============================] - 15s 484ms/step - loss: 0.5956 - accuracy: 0.7687 - val_loss: 0.7665 - val_accuracy: 0.6938

# %% [markdown]
# Ploting our Charts

# %%
! wget https://raw.githubusercontent.com/LiganiumInc/Helper-Functions/master/helper_functions.py
# Out:
# --2022-09-12 02:03:32--  https://raw.githubusercontent.com/LiganiumInc/Helper-Functions/master/helper_functions.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10246 (10K) [text/plain]
# Saving to: ‘helper_functions.py’
#
# helper_functions.py 100%[===================>]  10.01K  --.-KB/s    in 0s
#
# 2022-09-12 02:03:32 (82.3 MB/s) - ‘helper_functions.py’ saved [10246/10246]

# %%
from helper_functions import make_confusion_matrix, plot_loss_curves, calculate_results

# %%
plot_loss_curves(history)

# %% [markdown]
# Display Classification Report

# %%
from sklearn.metrics import classification_report,confusion_matrix
from tensorflow.keras.models import load_model


# on crée un nouveau generateur  sur les données de test
test_generator1 = validation_datagen.flow_from_directory(
    validation_data_dir,
    target_size = (224,224),
    class_mode = "categorical",
    shuffle = False)

best_model = load_model('FRS_vgg.h5')
# Out:
# Found 171 images belonging to 3 classes.

# %%
import numpy as np

# %%
y_pred_proba = best_model.predict(test_generator1)


y_pred_class = np.argmax(y_pred_proba,axis=1)

y_true = test_generator1.classes

print(classification_report(y_true, y_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.81      0.78        73
#            1       0.65      0.66      0.65        50
#            2       0.74      0.65      0.69        48
#
#     accuracy                           0.72       171
#    macro avg       0.71      0.70      0.71       171
# weighted avg       0.72      0.72      0.72       171

# %% [markdown]
# Display Confusion Matrix

# %%
make_confusion_matrix(y_true,y_pred_class,['FRONT','REAR','SIDE'])

# %%
calculate_results(y_true,y_pred_class)
# Out:
# {'accuracy': 71.9298245614035,
#  'precision': 0.7192950954560862,
#  'recall': 0.7192982456140351,
#  'f1': 0.7180484889432361}
